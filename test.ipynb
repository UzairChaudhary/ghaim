# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: pandas>=1.2 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\muhammad uzair\documents\github\ghaim\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.1 is available.
# You should consider upgrading via the 'c:\Users\Muhammad Uzair\Documents\GitHub\ghaim\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("UAE_Temperature_file.csv", encoding='cp1252')
data
# Out:
#        Year  Month  Day  Temp_Max[?øC]  Temp_Mean[?øC]  Temp_Min[?øC]  \
# 0      2021      1   16           25.2            16.2            8.2
# 1      2022      5   15           36.4            28.4           20.6
# 2      2020     10   31           36.6            26.7           19.0
# 3      2020      9   27           43.7            33.3           25.4
# 4      2020      5   30           45.8            37.4           30.7
# ...     ...    ...  ...            ...             ...            ...
# 13449  2019      4    2           36.2            28.4           23.6
# 13450  2020      8    9           45.1            38.2           32.9
# 13451  2018      2   28           30.2            24.9           21.3
# 13452  2018      3    2           25.5            22.2           19.5
# 13453  2018      6   15           42.2            34.9           27.5
#
#       Weather Category  Unnamed: 7    Emirate
# 0      Cold and Cloudy         NaN  Abu Dhabi
# 1       Sunny and Warm         NaN  Abu Dhabi
# 2       Sunny and Warm         NaN  Abu Dhabi
# 3        Sunny and Hot         NaN  Abu Dhabi
# 4        Sunny and Hot         NaN  Abu Dhabi
# ...                ...         ...        ...
# 13449   Sunny and Warm         NaN   Fujairah
# 13450    Sunny and Hot         NaN   Fujairah
# 13451   Sunny and Warm         NaN   Fujairah
# 13452   Sunny and Warm         NaN   Fujairah
# 13453    Sunny and Hot         NaN   Fujairah
#
# [13454 rows x 9 columns]

# %%
#check whether the dataset is balanced or not
weather_counts = data["Weather Category"].value_counts()
temp_data = pd.DataFrame({
    "weather condition":weather_counts.index,
    "Counts":weather_counts.values
})

plt.figure(figsize = (18,8))
sns.barplot(x="weather condition", y="Counts", data = temp_data)
plt.xticks(rotation=90)
plt.show()
